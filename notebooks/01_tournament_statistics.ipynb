# %% [markdown]
# # Tournament Statistics — exploration
#
# Load `player_tournament_stats.parquet` and explore raw batting/bowling figures. Production logic lives in `data-pipeline/normalization/stats/`.

# %%
import pandas as pd
stats = pd.read_parquet('../data/processed/player_tournament_stats.parquet')
print(stats.shape)
stats[stats.batted].groupby('format')[['bat_runs','bat_average','bat_strike_rate']].describe()
