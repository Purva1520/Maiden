# %% [markdown]
# # Tournament Baselines
#
# Inspect per-tournament distributions used for normalization.

# %%
import pandas as pd
tb = pd.read_parquet('../data/processed/tournament_baselines.parquet')
tb[tb.metric=='bat_strike_rate'][['tournament_id','count','median','q25','q75']]
