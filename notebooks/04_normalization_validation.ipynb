# %% [markdown]
# # Normalization Validation
#
# Sanity-check normalized features: percentile range, direction, missingness.

# %%
import pandas as pd
stats = pd.read_parquet('../data/processed/player_tournament_stats.parquet')
pct = [c for c in stats.columns if c.endswith('_tourn_pct')]
stats[pct].describe().T[['min','50%','max']]  # expect min>=0, max<=100
